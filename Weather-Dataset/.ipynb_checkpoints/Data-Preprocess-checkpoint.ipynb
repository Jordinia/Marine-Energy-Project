# %% [markdown]
# # Weather Data Preprocess

# %%
import pandas as pd

# %%
# Read daily data
daily_data = pd.read_csv('./Raw-Dataset/weather-open-meteo-6.22S108.51E0m-daily.csv')
# Read hourly data
hourly_data = pd.read_csv('./Raw-Dataset/weather-open-meteo-6.22S108.51E0m.csv')

# %%
daily_data['time'] = pd.to_datetime(daily_data['time'])
hourly_data['time'] = pd.to_datetime(hourly_data['time'])

# %%
daily_data['date'] = daily_data['time'].dt.date
hourly_data['date'] = hourly_data['time'].dt.date

# %%
daily_data.rename(columns={'weather_code (wmo code)': 'daily_weather_code (wmo code)'}, inplace=True)

# %%
daily_data.head()
# Out:
#         time  daily_weather_code (wmo code)        date
# 0 2021-01-01                             53  2021-01-01
# 1 2021-01-02                             51  2021-01-02
# 2 2021-01-03                             63  2021-01-03
# 3 2021-01-04                             61  2021-01-04
# 4 2021-01-05                             63  2021-01-05

# %%
hourly_data.head()
# Out:
#                  time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0 2021-01-01 00:00:00                 27.0                        83
# 1 2021-01-01 01:00:00                 27.2                        81
# 2 2021-01-01 02:00:00                 27.0                        83
# 3 2021-01-01 03:00:00                 27.0                        84
# 4 2021-01-01 04:00:00                 26.9                        84
#
#    dew_point_2m (°C)  apparent_temperature (°C)  precipitation (mm)  \
# 0               23.9                       29.0                 0.8
# 1               23.8                       28.9                 0.5
# 2               24.0                       28.5                 0.2
# 3               24.0                       28.0                 0.1
# 4               24.0                       28.0                 0.1
#
#    rain (mm)  weather_code (wmo code)  pressure_msl (hPa)  cloud_cover (%)  \
# 0        0.8                       53              1008.8              100
# 1        0.5                       53              1008.3              100
# 2        0.2                       51              1007.7              100
# 3        0.1                       51              1007.4               74
# 4        0.1                       51              1007.3               57
#
#    wind_speed_100m (km/h)  wind_direction_100m (°)  wind_gusts_10m (km/h)  \
# 0                    29.3                      289                   37.1
# 1                    31.9                      284                   38.9
# 2                    35.1                      283                   41.8
# 3                    38.8                      285                   46.4
# 4                    38.6                      284                   47.2
#
#    is_day ()  direct_radiation (W/m²)        date
# 0          0                      0.0  2021-01-01
# 1          0                      0.0  2021-01-01
# 2          0                      0.0  2021-01-01
# 3          0                      0.0  2021-01-01
# 4          0                      0.0  2021-01-01

# %%
merged_data = hourly_data.merge(daily_data, on='date')

# %%
merged_data.head()
# Out:
#                time_x  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0 2021-01-01 00:00:00                 27.0                        83
# 1 2021-01-01 01:00:00                 27.2                        81
# 2 2021-01-01 02:00:00                 27.0                        83
# 3 2021-01-01 03:00:00                 27.0                        84
# 4 2021-01-01 04:00:00                 26.9                        84
#
#    dew_point_2m (°C)  apparent_temperature (°C)  precipitation (mm)  \
# 0               23.9                       29.0                 0.8
# 1               23.8                       28.9                 0.5
# 2               24.0                       28.5                 0.2
# 3               24.0                       28.0                 0.1
# 4               24.0                       28.0                 0.1
#
#    rain (mm)  weather_code (wmo code)  pressure_msl (hPa)  cloud_cover (%)  \
# 0        0.8                       53              1008.8              100
# 1        0.5                       53              1008.3              100
# 2        0.2                       51              1007.7              100
# 3        0.1                       51              1007.4               74
# 4        0.1                       51              1007.3               57
#
#    wind_speed_100m (km/h)  wind_direction_100m (°)  wind_gusts_10m (km/h)  \
# 0                    29.3                      289                   37.1
# 1                    31.9                      284                   38.9
# 2                    35.1                      283                   41.8
# 3                    38.8                      285                   46.4
# 4                    38.6                      284                   47.2
#
#    is_day ()  direct_radiation (W/m²)        date     time_y  \
# 0          0                      0.0  2021-01-01 2021-01-01
# 1          0                      0.0  2021-01-01 2021-01-01
# 2          0                      0.0  2021-01-01 2021-01-01
# 3          0                      0.0  2021-01-01 2021-01-01
# 4          0                      0.0  2021-01-01 2021-01-01
#
#    daily_weather_code (wmo code)
# 0                             53
# 1                             53
# 2                             53
# 3                             53
# 4                             53

# %%
merged_data.drop(columns=['date', 'time_y'], inplace=True)

# %%
merged_data.rename(columns={'time_x': 'time'}, inplace=True)

# %%
merged_data.head()
# Out:
#                  time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0 2021-01-01 00:00:00                 27.0                        83
# 1 2021-01-01 01:00:00                 27.2                        81
# 2 2021-01-01 02:00:00                 27.0                        83
# 3 2021-01-01 03:00:00                 27.0                        84
# 4 2021-01-01 04:00:00                 26.9                        84
#
#    dew_point_2m (°C)  apparent_temperature (°C)  precipitation (mm)  \
# 0               23.9                       29.0                 0.8
# 1               23.8                       28.9                 0.5
# 2               24.0                       28.5                 0.2
# 3               24.0                       28.0                 0.1
# 4               24.0                       28.0                 0.1
#
#    rain (mm)  weather_code (wmo code)  pressure_msl (hPa)  cloud_cover (%)  \
# 0        0.8                       53              1008.8              100
# 1        0.5                       53              1008.3              100
# 2        0.2                       51              1007.7              100
# 3        0.1                       51              1007.4               74
# 4        0.1                       51              1007.3               57
#
#    wind_speed_100m (km/h)  wind_direction_100m (°)  wind_gusts_10m (km/h)  \
# 0                    29.3                      289                   37.1
# 1                    31.9                      284                   38.9
# 2                    35.1                      283                   41.8
# 3                    38.8                      285                   46.4
# 4                    38.6                      284                   47.2
#
#    is_day ()  direct_radiation (W/m²)  daily_weather_code (wmo code)
# 0          0                      0.0                             53
# 1          0                      0.0                             53
# 2          0                      0.0                             53
# 3          0                      0.0                             53
# 4          0                      0.0                             53

# %%
merged_data.to_csv('merged_weather_data.csv', index=False)

print("Merging completed. Data saved to 'merged_weather_data.csv'")
# Out:
# Merging completed. Data saved to 'merged_weather_data.csv'

# %% [markdown]
# # Merge with marine

# %%
weather_data = merged_data

# Read preprocessed marine data
marine_data = pd.read_csv('./Raw-Dataset/marine-open-meteo-6.25S108.50E0m (2).csv')

# %%
weather_data.head()
# Out:
#                  time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0 2021-01-01 00:00:00                 27.0                        83
# 1 2021-01-01 01:00:00                 27.2                        81
# 2 2021-01-01 02:00:00                 27.0                        83
# 3 2021-01-01 03:00:00                 27.0                        84
# 4 2021-01-01 04:00:00                 26.9                        84
#
#    dew_point_2m (°C)  apparent_temperature (°C)  precipitation (mm)  \
# 0               23.9                       29.0                 0.8
# 1               23.8                       28.9                 0.5
# 2               24.0                       28.5                 0.2
# 3               24.0                       28.0                 0.1
# 4               24.0                       28.0                 0.1
#
#    rain (mm)  weather_code (wmo code)  pressure_msl (hPa)  cloud_cover (%)  \
# 0        0.8                       53              1008.8              100
# 1        0.5                       53              1008.3              100
# 2        0.2                       51              1007.7              100
# 3        0.1                       51              1007.4               74
# 4        0.1                       51              1007.3               57
#
#    wind_speed_100m (km/h)  wind_direction_100m (°)  wind_gusts_10m (km/h)  \
# 0                    29.3                      289                   37.1
# 1                    31.9                      284                   38.9
# 2                    35.1                      283                   41.8
# 3                    38.8                      285                   46.4
# 4                    38.6                      284                   47.2
#
#    is_day ()  direct_radiation (W/m²)  daily_weather_code (wmo code)
# 0          0                      0.0                             53
# 1          0                      0.0                             53
# 2          0                      0.0                             53
# 3          0                      0.0                             53
# 4          0                      0.0                             53

# %%
marine_data['time'] = pd.to_datetime(marine_data['time'])

# %%
marine_data.head()
# Out:
#                  time  wave_height (m)  wave_direction (°)  wave_period (s)  \
# 0 2021-01-01 00:00:00              NaN                 NaN              NaN
# 1 2021-01-01 01:00:00              NaN                 NaN              NaN
# 2 2021-01-01 02:00:00              NaN                 NaN              NaN
# 3 2021-01-01 03:00:00              NaN                 NaN              NaN
# 4 2021-01-01 04:00:00              NaN                 NaN              NaN
#
#    wind_wave_height (m)  wind_wave_direction (°)  wind_wave_period (s)  \
# 0                   NaN                      NaN                   NaN
# 1                   NaN                      NaN                   NaN
# 2                   NaN                      NaN                   NaN
# 3                   NaN                      NaN                   NaN
# 4                   NaN                      NaN                   NaN
#
#    wind_wave_peak_period (s)  swell_wave_height (m)  swell_wave_direction (°)  \
# 0                        NaN                    NaN                       NaN
# 1                        NaN                    NaN                       NaN
# 2                        NaN                    NaN                       NaN
# 3                        NaN                    NaN                       NaN
# 4                        NaN                    NaN                       NaN
#
#    swell_wave_period (s)  swell_wave_peak_period (s)  \
# 0                    NaN                         NaN
# 1                    NaN                         NaN
# 2                    NaN                         NaN
# 3                    NaN                         NaN
# 4                    NaN                         NaN
#
#    ocean_current_velocity (km/h)  ocean_current_direction (°)
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN

# %%
merged_data = weather_data.merge(marine_data, on='time')

# %%
merged_data.head()
# Out:
#                  time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0 2021-01-01 00:00:00                 27.0                        83
# 1 2021-01-01 01:00:00                 27.2                        81
# 2 2021-01-01 02:00:00                 27.0                        83
# 3 2021-01-01 03:00:00                 27.0                        84
# 4 2021-01-01 04:00:00                 26.9                        84
#
#    dew_point_2m (°C)  apparent_temperature (°C)  precipitation (mm)  \
# 0               23.9                       29.0                 0.8
# 1               23.8                       28.9                 0.5
# 2               24.0                       28.5                 0.2
# 3               24.0                       28.0                 0.1
# 4               24.0                       28.0                 0.1
#
#    rain (mm)  weather_code (wmo code)  pressure_msl (hPa)  cloud_cover (%)  \
# 0        0.8                       53              1008.8              100
# 1        0.5                       53              1008.3              100
# 2        0.2                       51              1007.7              100
# 3        0.1                       51              1007.4               74
# 4        0.1                       51              1007.3               57
#
#    ...  wind_wave_height (m)  wind_wave_direction (°)  wind_wave_period (s)  \
# 0  ...                   NaN                      NaN                   NaN
# 1  ...                   NaN                      NaN                   NaN
# 2  ...                   NaN                      NaN                   NaN
# 3  ...                   NaN                      NaN                   NaN
# 4  ...                   NaN                      NaN                   NaN
#
#    wind_wave_peak_period (s)  swell_wave_height (m)  swell_wave_direction (°)  \
# 0                        NaN                    NaN                       NaN
# 1                        NaN                    NaN                       NaN
# 2                        NaN                    NaN                       NaN
# 3                        NaN                    NaN                       NaN
# 4                        NaN                    NaN                       NaN
#
#    swell_wave_period (s)  swell_wave_peak_period (s)  \
# 0                    NaN                         NaN
# 1                    NaN                         NaN
# 2                    NaN                         NaN
# 3                    NaN                         NaN
# 4                    NaN                         NaN
#
#    ocean_current_velocity (km/h)  ocean_current_direction (°)
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
# [5 rows x 29 columns]

# %%
merged_data.to_csv('merged_weather_marine_data.csv', index=False)

print("Merging completed. Data saved to 'merged_weather_marine_data.csv'")
# Out:
# Merging completed. Data saved to 'merged_weather_marine_data.csv'
