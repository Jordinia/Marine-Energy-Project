# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense, Conv1D, MaxPool1D, Flatten, Dropout, GRU, TimeDistributed # importing dense layer
from tensorflow.keras.models import Sequential #importing Sequential layer
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model

# %%
#Load Dataset
data_path = '/content/drive/MyDrive/merged_weather_marine_data.csv'
data=pd.read_csv(data_path)

# %%
#Cleaning and Preprocessing
print(data.describe())

#column temperature (min, max, avg), precipitation, snow, wind(speed, direction, peak gust), pressure, sunshine duration
print(data.columns)

#melihat info descriptive statistic
print(data.describe())

#melihat banyaknya missing value
print(data.isnull().sum())

#melihat banyaknya entri unique
print(data.nunique())

# Menentukan kolom-kolom yang bertipe object
object_cols = data.select_dtypes(include=['object']).columns
df = data.drop(columns=object_cols)

df = df.dropna()   #58 row is dropped
#df['sail_decision'] = 1
print(df.columns)
print(df.shape)
# Out:
#        temperature_2m (°C)  relative_humidity_2m (%)  dew_point_2m (°C)  \
# count         26304.000000              26304.000000       26304.000000
# mean             27.655056                 77.906060          23.403665
# std               0.975380                  5.904932           0.954461
# min              23.500000                 54.000000          17.600000
# 25%              27.000000                 74.000000          23.000000
# 50%              27.700000                 78.000000          23.600000
# 75%              28.400000                 82.000000          24.000000
# max              31.100000                 95.000000          26.200000
#
#        apparent_temperature (°C)  precipitation (mm)     rain (mm)  \
# count               26304.000000        26304.000000  26304.000000
# mean                   31.119514            0.231858      0.231858
# std                     1.929716            0.720542      0.720542
# min                    24.600000            0.000000      0.000000
# 25%                    29.800000            0.000000      0.000000
# 50%                    31.200000            0.000000      0.000000
# 75%                    32.500000            0.100000      0.100000
# max                    37.300000           14.200000     14.200000
#
#        weather_code (wmo code)  pressure_msl (hPa)  cloud_cover (%)  \
# count             26304.000000        26304.000000     26304.000000
# mean                 16.583295         1009.703562        43.812234
# std                  24.172228            1.808826        28.525188
# min                   0.000000         1003.900000         0.000000
# 25%                   1.000000         1008.400000        26.000000
# 50%                   1.000000         1009.700000        37.000000
# 75%                  51.000000         1011.000000        62.000000
# max                  65.000000         1016.100000       100.000000
#
#        wind_speed_100m (km/h)  ...  wind_wave_height (m)  \
# count            26304.000000  ...          19742.000000
# mean                18.612740  ...              0.205135
# std                  9.670412  ...              0.253668
# min                  0.000000  ...              0.000000
# 25%                 11.000000  ...              0.020000
# 50%                 17.700000  ...              0.120000
# 75%                 24.900000  ...              0.300000
# max                 53.500000  ...              1.680000
#
#        wind_wave_direction (°)  wind_wave_period (s)  \
# count             19742.000000          19742.000000
# mean                114.389424              1.725479
# std                 106.015064              1.005221
# min                -180.000000              0.000000
# 25%                  67.000000              1.000000
# 50%                 125.000000              1.700000
# 75%                 180.000000              2.350000
# max                 359.000000              5.350000
#
#        wind_wave_peak_period (s)  swell_wave_height (m)  \
# count               12521.000000           19742.000000
# mean                    2.305658               0.383231
# std                     1.137879               0.200268
# min                     0.750000               0.020000
# 25%                     1.350000               0.240000
# 50%                     2.200000               0.380000
# 75%                     2.950000               0.500000
# max                     6.950000               1.340000
#
#        swell_wave_direction (°)  swell_wave_period (s)  \
# count              19742.000000           19742.000000
# mean                 105.776872               4.407213
# std                  135.337500               1.170228
# min                 -178.000000               1.150000
# 25%                   51.000000               3.650000
# 50%                   82.000000               4.550000
# 75%                  155.000000               5.250000
# max                  360.000000               9.250000
#
#        swell_wave_peak_period (s)  ocean_current_velocity (km/h)  \
# count                12521.000000                   17537.000000
# mean                     5.805910                       0.744141
# std                      1.078656                       0.494500
# min                      1.850000                       0.000000
# 25%                      5.200000                       0.400000
# 50%                      5.750000                       0.600000
# 75%                      6.350000                       1.000000
# max                     11.300000                       2.700000
#
#        ocean_current_direction (°)
# count                 17537.000000
# mean                    200.275874
# std                     104.241085
# min                       0.000000
# 25%                     117.000000
# 50%                     180.000000
# 75%                     304.000000
# max                     346.000000
#
# [8 rows x 28 columns]
# Index(['time', 'temperature_2m (°C)', 'relative_humidity_2m (%)',
#        'dew_point_2m (°C)', 'apparent_temperature (°C)', 'precipitation (mm)',
#        'rain (mm)', 'weather_code (wmo code)', 'pressure_msl (hPa)',
#        'cloud_cover (%)', 'wind_speed_100m (km/h)', 'wind_direction_100m (°)',
#        'wind_gusts_10m (km/h)', 'is_day ()', 'direct_radiation (W/m²)',
#        'daily_weather_code (wmo code)', 'wave_height (m)',
#        'wave_direction (°)', 'wave_period (s)', 'wind_wave_height (m)',
#        'wind_wave_direction (°)', 'wind_wave_period (s)',
#        'wind_wave_peak_period (s)', 'swell_wave_height (m)',
#        'swell_wave_direction (°)', 'swell_wave_period (s)',
#        'swell_wave_peak_period (s)', 'ocean_current_velocity (km/h)',
#        'ocean_current_direction (°)'],
#       dtype='object')
#        temperature_2m (°C)  relative_humidity_2m (%)  dew_point_2m (°C)  \
# count         26304.000000              26304.000000       26304.000000
# mean             27.655056                 77.906060          23.403665
# std               0.975380                  5.904932           0.954461
# min              23.500000                 54.000000          17.600000
# 25%              27.000000                 74.000000          23.000000
# 50%              27.700000                 78.000000          23.600000
# 75%              28.400000                 82.000000          24.000000
# max              31.100000                 95.000000          26.200000
#
#        apparent_temperature (°C)  precipitation (mm)     rain (mm)  \
# count               26304.000000        26304.000000  26304.000000
# mean                   31.119514            0.231858      0.231858
# std                     1.929716            0.720542      0.720542
# min                    24.600000            0.000000      0.000000
# 25%                    29.800000            0.000000      0.000000
# 50%                    31.200000            0.000000      0.000000
# 75%                    32.500000            0.100000      0.100000
# max                    37.300000           14.200000     14.200000
#
#        weather_code (wmo code)  pressure_msl (hPa)  cloud_cover (%)  \
# count             26304.000000        26304.000000     26304.000000
# mean                 16.583295         1009.703562        43.812234
# std                  24.172228            1.808826        28.525188
# min                   0.000000         1003.900000         0.000000
# 25%                   1.000000         1008.400000        26.000000
# 50%                   1.000000         1009.700000        37.000000
# 75%                  51.000000         1011.000000        62.000000
# max                  65.000000         1016.100000       100.000000
#
#        wind_speed_100m (km/h)  ...  wind_wave_height (m)  \
# count            26304.000000  ...          19742.000000
# mean                18.612740  ...              0.205135
# std                  9.670412  ...              0.253668
# min                  0.000000  ...              0.000000
# 25%                 11.000000  ...              0.020000
# 50%                 17.700000  ...              0.120000
# 75%                 24.900000  ...              0.300000
# max                 53.500000  ...              1.680000
#
#        wind_wave_direction (°)  wind_wave_period (s)  \
# count             19742.000000          19742.000000
# mean                114.389424              1.725479
# std                 106.015064              1.005221
# min                -180.000000              0.000000
# 25%                  67.000000              1.000000
# 50%                 125.000000              1.700000
# 75%                 180.000000              2.350000
# max                 359.000000              5.350000
#
#        wind_wave_peak_period (s)  swell_wave_height (m)  \
# count               12521.000000           19742.000000
# mean                    2.305658               0.383231
# std                     1.137879               0.200268
# min                     0.750000               0.020000
# 25%                     1.350000               0.240000
# 50%                     2.200000               0.380000
# 75%                     2.950000               0.500000
# max                     6.950000               1.340000
#
#        swell_wave_direction (°)  swell_wave_period (s)  \
# count              19742.000000           19742.000000
# mean                 105.776872               4.407213
# std                  135.337500               1.170228
# min                 -178.000000               1.150000
# 25%                   51.000000               3.650000
# 50%                   82.000000               4.550000
# 75%                  155.000000               5.250000
# max                  360.000000               9.250000
#
#        swell_wave_peak_period (s)  ocean_current_velocity (km/h)  \
# count                12521.000000                   17537.000000
# mean                     5.805910                       0.744141
# std                      1.078656                       0.494500
# min                      1.850000                       0.000000
# 25%                      5.200000                       0.400000
# 50%                      5.750000                       0.600000
# 75%                      6.350000                       1.000000
# max                     11.300000                       2.700000
#
#        ocean_current_direction (°)
# count                 17537.000000
# mean                    200.275874
# std                     104.241085
# min                       0.000000
# 25%                     117.000000
# 50%                     180.000000
# 75%                     304.000000
# max                     346.000000
#
# [8 rows x 28 columns]
# time                                 0
# temperature_2m (°C)                  0
# relative_humidity_2m (%)             0
# dew_point_2m (°C)                    0
# apparent_temperature (°C)            0
# precipitation (mm)                   0
# rain (mm)                            0
# weather_code (wmo code)              0
# pressure_msl (hPa)                   0
# cloud_cover (%)                      0
# wind_speed_100m (km/h)               0
# wind_direction_100m (°)              0
# wind_gusts_10m (km/h)                0
# is_day ()                            0
# direct_radiation (W/m²)              0
# daily_weather_code (wmo code)        0
# wave_height (m)                   6562
# wave_direction (°)                6562
# wave_period (s)                   6562
# wind_wave_height (m)              6562
# wind_wave_direction (°)           6562
# wind_wave_period (s)              6562
# wind_wave_peak_period (s)        13783
# swell_wave_height (m)             6562
# swell_wave_direction (°)          6562
# swell_wave_period (s)             6562
# swell_wave_peak_period (s)       13783
# ocean_current_velocity (km/h)     8767
# ocean_current_direction (°)       8767
# dtype: int64
# time                             26304
# temperature_2m (°C)                 71
# relative_humidity_2m (%)            41
# dew_point_2m (°C)                   81
# apparent_temperature (°C)          120
# precipitation (mm)                  97
# rain (mm)                           97
# weather_code (wmo code)             10
# pressure_msl (hPa)                 121
# cloud_cover (%)                    101
# wind_speed_100m (km/h)             501
# wind_direction_100m (°)            360
# wind_gusts_10m (km/h)              162
# is_day ()                            2
# direct_radiation (W/m²)            881
# daily_weather_code (wmo code)       10
# wave_height (m)                     92
# wave_direction (°)                 507
# wave_period (s)                    133
# wind_wave_height (m)                83
# wind_wave_direction (°)            530
# wind_wave_period (s)               108
# wind_wave_peak_period (s)          118
# swell_wave_height (m)               65
# swell_wave_direction (°)           498
# swell_wave_period (s)              142
# swell_wave_peak_period (s)         158
# ocean_current_velocity (km/h)       26
# ocean_current_direction (°)         87
# dtype: int64
# Index(['temperature_2m (°C)', 'relative_humidity_2m (%)', 'dew_point_2m (°C)',
#        'apparent_temperature (°C)', 'precipitation (mm)', 'rain (mm)',
#        'weather_code (wmo code)', 'pressure_msl (hPa)', 'cloud_cover (%)',
#        'wind_speed_100m (km/h)', 'wind_direction_100m (°)',
#        'wind_gusts_10m (km/h)', 'is_day ()', 'direct_radiation (W/m²)',
#        'daily_weather_code (wmo code)', 'wave_height (m)',
#        'wave_direction (°)', 'wave_period (s)', 'wind_wave_height (m)',
#        'wind_wave_direction (°)', 'wind_wave_period (s)',
#        'wind_wave_peak_period (s)', 'swell_wave_height (m)',
#        'swell_wave_direction (°)', 'swell_wave_period (s)',
#        'swell_wave_peak_period (s)', 'ocean_current_velocity (km/h)',
#        'ocean_current_direction (°)'],
#       dtype='object')
# (12521, 28)

# %%
def is_safe_to_sail(row):
    # Kriteria kondisi aman
    if (20 <= row['temperature_2m (°C)'] <= 30 and
        row['precipitation (mm)'] == 0 and
        row['wind_speed_10m (km/h)'] < 15 and
        row['wave_height (m)'] <= 1.5 and
        row['cloud_cover (%)'] < 70 and
        row['wind_speed_10m_max (km/h)'] < 20 and
        row['wave_height_max (m)'] <= 2.0 and
        row['wind_wave_height (m)'] <= 1.0 and
        row['swell_wave_height (m)'] <= 1.5 and
        row['weather_code (wmo code)'] in [0, 1, 2, 3, 4]):
        return 'yes'
    else:
        return 'no'

df['safe_to_sail'] = df.apply(is_safe_to_sail, axis=1)
# write-back to csv

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(df)

print(data_scaled.shape)

#turn into sequence
steps= 20
inp = []
out = []
for i in range(len(data_scaled) - (steps)):
    inp.append(data_scaled[i:i+steps])
    out.append(data_scaled[i+steps])

print(len(inp)) #input panjangnya 210, output panjangnya 20
# # print(inp)

inp= np.asanyarray(inp)
out= np.asanyarray(out)

print(inp.shape)
print(out.shape)

train_test_ratio = 0.7
train_size = int(train_test_ratio * data_scaled.shape[0])
print(train_size)

#180 data for train, 30 data for test
x_train_tseries = inp[:train_size,:,:]
x_test_tseries = inp[train_size:,:,:]
y_train_tseries = out[:train_size]
y_test_tseries= out[train_size:]

print(x_train_tseries.shape)
print(x_test_tseries.shape)
print(y_train_tseries.shape)
print(y_test_tseries.shape)

#feature engineering data static
# Out:
# (12521, 28)
# 12501
# (12501, 20, 28)
# (12501, 28)
# 8764
# (8764, 20, 28)
# (3737, 20, 28)
# (8764, 28)
# (3737, 28)

# %%
input_tseries = Input(shape=(x_train_tseries.shape[1], x_train_tseries.shape[2]))
gru_out = GRU(32, return_sequences=True)(input_tseries)
time_dist1 = TimeDistributed(Dense(units=8, activation = 'relu'))(gru_out)
flatten = Flatten()(time_dist1)   #apa tambah layer 168 neuron, 84, 42
temp_our = Dense(32)(flatten)
gru_out_binary = Dense(1, activation='sigmoid', name='binary_output')(flatten) #ini bisa jadi dihapus

input_static = Input(shape=(x_train_static.shape[1],))
combined = Concatenate()([temp_our, input_static])

x = Dense(64, activation='relu')(combined)
x = Dense(32, activation='relu')(x)
x = Dense(1, activation='relu', name='regression_output')(x)

# %%
weather_model = Model(inputs=[input_tseries, input_static], outputs=[gru_out_binary, out])

# Kompilasi model
weather_model.compile(optimizer=Adam(),
              loss={'binary_output': 'binary_crossentropy', 'regression_output': 'mse'},
              metrics={'binary_output': 'accuracy', 'regression_output': 'mae'})

weather_model.summary()

# %%
history = weather_model.fit([x_train_tseries, x_train_static],
                    {'binary_output': y_train_binary, 'regression_output': y_train_regression},
                    epochs=50, batch_size=32, validation_split=0.2)

# %%
results = model.evaluate([x_test_tseries, x_test_static],
                         {'binary_output': y_test_binary, 'regression_output': y_test_regression})

# %%
#Memprediksi beberapa waktu ke-depan, inverse scaler nya belum dipasang
forecast_binary, forecast_regression = weather_model.predict([x_forecast_tseries, x_forecast_static])  #x_forecast nanti harus diganti

print("Prediksi Biner:", forecast_binary)
print("Prediksi Regresi:", forecast_regression)

# Ulangi prediksi untuk 7 hari ke depan
forecast_days = 7
forecasts_binary = []
forecasts_regression = []

for _ in range(forecast_days):
    forecast_binary, forecast_regression = weather_model.predict([x_forecast_tseries, x_forecast_static])
    forecasts_binary.append(forecast_binary[0][0])
    forecasts_regression.append(forecast_regression[0][0])

    # Update data untuk hari berikutnya
    x_forecast_tseries = np.roll(x_forecast_tseries, -1, axis=1)
    x_forecast_tseries[0, -1, :] = forecast_regression[0][0]  # Anggap prediksi regresi sebagai fitur untuk timestep berikutnya

print("Prediksi Biner untuk 7 hari ke depan:", forecasts_binary)
print("Prediksi Regresi untuk 7 hari ke depan:", forecasts_regression)

# %% [markdown]
# **Non seq2seq without static data, output only binary**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GRU, Dense, Concatenate, Flatten, Lambda
from tensorflow.keras.optimizers import Adam

# Hyperparameters
input_seq_len = x_train_tseries.shape[1]
num_features = x_train_tseries.shape[2]
target_seq_len = x_train_tseries.shape[1]#y_train.shape[1]  # Number of steps to predict
latent_dim = 32  # Dimension of the latent space

# input_seq_len = 10
# num_features = 20
# target_seq_len = 8  # Number of steps to predict
# latent_dim = 64  # Dimension of the latent space

# Example data preparation, bagian ini nanti diganti jadi data tseries
# x_train = np.random.rand(1000, 10, num_features)  # 1000 samples, 10 time steps, num_features features
# y_train = np.random.rand(1000, 7, num_features)   # 1000 samples, 7 time steps, num_features features
# x_train_static = np.random.rand(1000, 5)          # 1000 samples, 5 static features
# y_train_binary = np.random.randint(0, 2, size=(1000, 1))  # 1000 samples, binary output

# Define the GRU model
input_seq = Input(shape=(input_seq_len, num_features))
#static_input = Input(shape=(x_train_static.shape[1],))

gru_out = GRU(latent_dim, return_sequences=True)(input_seq)
seq_output = Dense(num_features, activation='linear')(gru_out)

# Flatten the sequence output
flatten_seq = Flatten()(seq_output)

# Concatenate the sequence output with static data
#combined = Concatenate()([flatten_seq, static_input])

# Dense layers for binary classification
x = Dense(64, activation='relu')(flatten_seq)
x = Dense(32, activation='relu')(x)
x = Dense(16, activation='relu')(x)
binary_output = Dense(1, activation='sigmoid', name='binary_output')(x)

# Define and compile the final model
model = Model(inputs=input_seq, outputs=binary_output)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

# Train the model
model.fit(x_train, y_train_binary, epochs=50, batch_size=32, validation_split=0.2)

# Function to predict sequence output and binary classification
def predict_sequence_and_binary(input_seq, static_input, model):
    #binary_output = model.predict([input_seq, static_input])
    binary_output = model.predict(input_seq)
    return binary_output

# Example usage
input_seq = x_train[:1]  # Take the first sample from training data
static_input = x_train_static[:1]
binary_prediction = predict_sequence_and_binary(input_seq, static_input, model)

#print("Predicted Sequence:", predicted_sequence)
print("Binary Prediction:", binary_prediction)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 20, 28)]          0
#
#  gru_1 (GRU)                 (None, 20, 32)            5952
#
#  dense_4 (Dense)             (None, 20, 28)            924
#
#  flatten_1 (Flatten)         (None, 560)               0
#
#  dense_5 (Dense)             (None, 64)                35904
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dense_7 (Dense)             (None, 16)                528
#
#  binary_output (Dense)       (None, 1)                 17
#
# =================================================================
# Total params: 45405 (177.36 KB)
# Trainable params: 45405 (177.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-c4117fc77d30> in <cell line: 49>()
#      47
#      48 # Train the model
# ---> 49 model.fit(x_train, y_train_binary, epochs=50, batch_size=32, validation_split=0.2)
#      50
#      51 # Function to predict sequence output and binary classification
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1401, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1384, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1373, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1150, in train_step
#         y_pred = self(x, training=True)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "model_1" is incompatible with the layer: expected shape=(None, 20, 28), found shape=(32, 10, 28)

# %% [markdown]
# **Non Seq2seq with static data**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GRU, Dense, Concatenate, Flatten, Lambda
from tensorflow.keras.optimizers import Adam

# Hyperparameters
# input_seq_len = x_train_tseries.shape[1]
# num_features = x_train_tseries.shape[2]
# target_seq_len = y_train.shape[1]  # Number of steps to predict
# latent_dim = 64  # Dimension of the latent space

input_seq_len = 10
num_features = 20
target_seq_len = 10  # Number of steps to predict
latent_dim = 64  # Dimension of the latent space

# Example data preparation  nanti ini diganti sama tseries
x_train = np.random.rand(1000, input_seq_len, num_features)  # 1000 samples, 10 time steps, num_features features
y_train = np.random.rand(1000, target_seq_len, num_features)   # 1000 samples, 10 time steps, num_features features
x_train_static = np.random.rand(1000, 5)          # 1000 samples, 5 static features
y_train_binary = np.random.randint(0, 2, size=(1000, 1))  # 1000 samples, binary output

# Define the GRU model
input_seq = Input(shape=(input_seq_len, num_features))
static_input = Input(shape=(x_train_static.shape[1],))

gru_out = GRU(latent_dim, return_sequences=True)(input_seq)
seq_output = Dense(num_features, activation='linear')(gru_out)

# Flatten the sequence output
flatten_seq = Flatten()(seq_output)

# Concatenate the sequence output with static data
combined = Concatenate()([flatten_seq, static_input])

# Dense layers for binary classification
x = Dense(64, activation='relu')(combined)
x = Dense(32, activation='relu')(x)
binary_output = Dense(1, activation='sigmoid', name='binary_output')(x)

# Define and compile the final model
model = Model(inputs=[input_seq, static_input], outputs=[seq_output, binary_output])
model.compile(optimizer='adam', loss=['mse', 'binary_crossentropy'], metrics=['accuracy'])

# Train the model
model.fit([x_train, x_train_static], [y_train, y_train_binary], epochs=50, batch_size=32, validation_split=0.2)

# Function to predict sequence output and binary classification
def predict_sequence_and_binary(input_seq, static_input, model):
    seq_output, binary_output = model.predict([input_seq, static_input])
    return seq_output, binary_output

# Example usage
input_seq = x_train[:1]  # Take the first sample from training data
static_input = x_train_static[:1]
predicted_sequence, binary_prediction = predict_sequence_and_binary(input_seq, static_input, model)

print("Predicted Sequence:", predicted_sequence)
print("Binary Prediction:", binary_prediction)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 5s 39ms/step - loss: 0.8690 - dense_30_loss: 0.1725 - binary_output_loss: 0.6965 - dense_30_accuracy: 0.0500 - binary_output_accuracy: 0.4825 - val_loss: 0.7987 - val_dense_30_loss: 0.1046 - val_binary_output_loss: 0.6941 - val_dense_30_accuracy: 0.0515 - val_binary_output_accuracy: 0.4850
# Epoch 2/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.7951 - dense_30_loss: 0.1025 - binary_output_loss: 0.6927 - dense_30_accuracy: 0.0507 - binary_output_accuracy: 0.5200 - val_loss: 0.7949 - val_dense_30_loss: 0.0982 - val_binary_output_loss: 0.6966 - val_dense_30_accuracy: 0.0480 - val_binary_output_accuracy: 0.5250
# Epoch 3/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.7901 - dense_30_loss: 0.0977 - binary_output_loss: 0.6924 - dense_30_accuracy: 0.0500 - binary_output_accuracy: 0.5038 - val_loss: 0.7961 - val_dense_30_loss: 0.0957 - val_binary_output_loss: 0.7004 - val_dense_30_accuracy: 0.0540 - val_binary_output_accuracy: 0.4850
# Epoch 4/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.7899 - dense_30_loss: 0.0956 - binary_output_loss: 0.6943 - dense_30_accuracy: 0.0527 - binary_output_accuracy: 0.4950 - val_loss: 0.7910 - val_dense_30_loss: 0.0947 - val_binary_output_loss: 0.6963 - val_dense_30_accuracy: 0.0525 - val_binary_output_accuracy: 0.4650
# Epoch 5/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.7862 - dense_30_loss: 0.0956 - binary_output_loss: 0.6906 - dense_30_accuracy: 0.0490 - binary_output_accuracy: 0.5437 - val_loss: 0.8516 - val_dense_30_loss: 0.1050 - val_binary_output_loss: 0.7467 - val_dense_30_accuracy: 0.0480 - val_binary_output_accuracy: 0.5250
# Epoch 6/50
# 25/25 [==============================] - 0s 15ms/step - loss: 0.7941 - dense_30_loss: 0.0990 - binary_output_loss: 0.6951 - dense_30_accuracy: 0.0492 - binary_output_accuracy: 0.5400 - val_loss: 0.7875 - val_dense_30_loss: 0.0939 - val_binary_output_loss: 0.6937 - val_dense_30_accuracy: 0.0525 - val_binary_output_accuracy: 0.5200
# Epoch 7/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.7838 - dense_30_loss: 0.0929 - binary_output_loss: 0.6909 - dense_30_accuracy: 0.0542 - binary_output_accuracy: 0.5088 - val_loss: 0.7905 - val_dense_30_loss: 0.0921 - val_binary_output_loss: 0.6984 - val_dense_30_accuracy: 0.0515 - val_binary_output_accuracy: 0.5100
# Epoch 8/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.7751 - dense_30_loss: 0.0918 - binary_output_loss: 0.6833 - dense_30_accuracy: 0.0516 - binary_output_accuracy: 0.5462 - val_loss: 0.7857 - val_dense_30_loss: 0.0913 - val_binary_output_loss: 0.6944 - val_dense_30_accuracy: 0.0535 - val_binary_output_accuracy: 0.5050
# Epoch 9/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.7719 - dense_30_loss: 0.0914 - binary_output_loss: 0.6805 - dense_30_accuracy: 0.0527 - binary_output_accuracy: 0.5625 - val_loss: 0.7884 - val_dense_30_loss: 0.0914 - val_binary_output_loss: 0.6970 - val_dense_30_accuracy: 0.0530 - val_binary_output_accuracy: 0.4550
# Epoch 10/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.7686 - dense_30_loss: 0.0913 - binary_output_loss: 0.6772 - dense_30_accuracy: 0.0521 - binary_output_accuracy: 0.5675 - val_loss: 0.7927 - val_dense_30_loss: 0.0913 - val_binary_output_loss: 0.7014 - val_dense_30_accuracy: 0.0570 - val_binary_output_accuracy: 0.5300
# Epoch 11/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.7660 - dense_30_loss: 0.0916 - binary_output_loss: 0.6743 - dense_30_accuracy: 0.0495 - binary_output_accuracy: 0.5650 - val_loss: 0.7910 - val_dense_30_loss: 0.0920 - val_binary_output_loss: 0.6990 - val_dense_30_accuracy: 0.0490 - val_binary_output_accuracy: 0.4850
# Epoch 12/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.7772 - dense_30_loss: 0.0931 - binary_output_loss: 0.6842 - dense_30_accuracy: 0.0515 - binary_output_accuracy: 0.5638 - val_loss: 0.7967 - val_dense_30_loss: 0.0961 - val_binary_output_loss: 0.7006 - val_dense_30_accuracy: 0.0490 - val_binary_output_accuracy: 0.4750
# Epoch 13/50
# 25/25 [==============================] - 0s 14ms/step - loss: 0.7601 - dense_30_loss: 0.0935 - binary_output_loss: 0.6666 - dense_30_accuracy: 0.0470 - binary_output_accuracy: 0.6300 - val_loss: 0.7981 - val_dense_30_loss: 0.0930 - val_binary_output_loss: 0.7052 - val_dense_30_accuracy: 0.0465 - val_binary_output_accuracy: 0.4650
# Epoch 14/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.7650 - dense_30_loss: 0.0936 - binary_output_loss: 0.6714 - dense_30_accuracy: 0.0521 - binary_output_accuracy: 0.5950 - val_loss: 0.8343 - val_dense_30_loss: 0.0980 - val_binary_output_loss: 0.7363 - val_dense_30_accuracy: 0.0555 - val_binary_output_accuracy: 0.4800
# Epoch 15/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.7507 - dense_30_loss: 0.0946 - binary_output_loss: 0.6561 - dense_30_accuracy: 0.0491 - binary_output_accuracy: 0.6112 - val_loss: 0.8119 - val_dense_30_loss: 0.0946 - val_binary_output_loss: 0.7173 - val_dense_30_accuracy: 0.0585 - val_binary_output_accuracy: 0.5050
# Epoch 16/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.7582 - dense_30_loss: 0.0954 - binary_output_loss: 0.6627 - dense_30_accuracy: 0.0487 - binary_output_accuracy: 0.6037 - val_loss: 0.8144 - val_dense_30_loss: 0.0965 - val_binary_output_loss: 0.7179 - val_dense_30_accuracy: 0.0545 - val_binary_output_accuracy: 0.4350
# Epoch 17/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.7658 - dense_30_loss: 0.0971 - binary_output_loss: 0.6687 - dense_30_accuracy: 0.0519 - binary_output_accuracy: 0.5700 - val_loss: 0.8348 - val_dense_30_loss: 0.0981 - val_binary_output_loss: 0.7366 - val_dense_30_accuracy: 0.0535 - val_binary_output_accuracy: 0.5250
# Epoch 18/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.7617 - dense_30_loss: 0.1015 - binary_output_loss: 0.6602 - dense_30_accuracy: 0.0483 - binary_output_accuracy: 0.5913 - val_loss: 0.8247 - val_dense_30_loss: 0.0987 - val_binary_output_loss: 0.7261 - val_dense_30_accuracy: 0.0535 - val_binary_output_accuracy: 0.4250
# Epoch 19/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.7374 - dense_30_loss: 0.0976 - binary_output_loss: 0.6398 - dense_30_accuracy: 0.0526 - binary_output_accuracy: 0.6425 - val_loss: 0.8426 - val_dense_30_loss: 0.0998 - val_binary_output_loss: 0.7429 - val_dense_30_accuracy: 0.0500 - val_binary_output_accuracy: 0.5250
# Epoch 20/50
# 25/25 [==============================] - 0s 13ms/step - loss: 0.7272 - dense_30_loss: 0.0976 - binary_output_loss: 0.6296 - dense_30_accuracy: 0.0509 - binary_output_accuracy: 0.6350 - val_loss: 0.8413 - val_dense_30_loss: 0.0985 - val_binary_output_loss: 0.7428 - val_dense_30_accuracy: 0.0530 - val_binary_output_accuracy: 0.4550
# Epoch 21/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.7243 - dense_30_loss: 0.0987 - binary_output_loss: 0.6256 - dense_30_accuracy: 0.0520 - binary_output_accuracy: 0.6300 - val_loss: 0.8792 - val_dense_30_loss: 0.1008 - val_binary_output_loss: 0.7784 - val_dense_30_accuracy: 0.0500 - val_binary_output_accuracy: 0.5000
# Epoch 22/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.7204 - dense_30_loss: 0.1003 - binary_output_loss: 0.6201 - dense_30_accuracy: 0.0520 - binary_output_accuracy: 0.6687 - val_loss: 0.8709 - val_dense_30_loss: 0.1001 - val_binary_output_loss: 0.7708 - val_dense_30_accuracy: 0.0510 - val_binary_output_accuracy: 0.4400
# Epoch 23/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.7090 - dense_30_loss: 0.1000 - binary_output_loss: 0.6090 - dense_30_accuracy: 0.0507 - binary_output_accuracy: 0.6675 - val_loss: 0.8807 - val_dense_30_loss: 0.1004 - val_binary_output_loss: 0.7802 - val_dense_30_accuracy: 0.0525 - val_binary_output_accuracy: 0.4500
# Epoch 24/50
# 25/25 [==============================] - 0s 14ms/step - loss: 0.6952 - dense_30_loss: 0.0995 - binary_output_loss: 0.5957 - dense_30_accuracy: 0.0510 - binary_output_accuracy: 0.6850 - val_loss: 0.9022 - val_dense_30_loss: 0.1001 - val_binary_output_loss: 0.8021 - val_dense_30_accuracy: 0.0505 - val_binary_output_accuracy: 0.4950
# Epoch 25/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.6903 - dense_30_loss: 0.1002 - binary_output_loss: 0.5902 - dense_30_accuracy: 0.0507 - binary_output_accuracy: 0.6925 - val_loss: 0.9063 - val_dense_30_loss: 0.1011 - val_binary_output_loss: 0.8052 - val_dense_30_accuracy: 0.0525 - val_binary_output_accuracy: 0.4600
# Epoch 26/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.6793 - dense_30_loss: 0.0999 - binary_output_loss: 0.5794 - dense_30_accuracy: 0.0501 - binary_output_accuracy: 0.7050 - val_loss: 0.9165 - val_dense_30_loss: 0.1002 - val_binary_output_loss: 0.8163 - val_dense_30_accuracy: 0.0520 - val_binary_output_accuracy: 0.4550
# Epoch 27/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.6716 - dense_30_loss: 0.0996 - binary_output_loss: 0.5720 - dense_30_accuracy: 0.0490 - binary_output_accuracy: 0.7125 - val_loss: 0.9246 - val_dense_30_loss: 0.1006 - val_binary_output_loss: 0.8241 - val_dense_30_accuracy: 0.0525 - val_binary_output_accuracy: 0.4650
# Epoch 28/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.6917 - dense_30_loss: 0.1024 - binary_output_loss: 0.5893 - dense_30_accuracy: 0.0499 - binary_output_accuracy: 0.6963 - val_loss: 0.9388 - val_dense_30_loss: 0.1073 - val_binary_output_loss: 0.8315 - val_dense_30_accuracy: 0.0490 - val_binary_output_accuracy: 0.4650
# Epoch 29/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.6647 - dense_30_loss: 0.1026 - binary_output_loss: 0.5621 - dense_30_accuracy: 0.0514 - binary_output_accuracy: 0.7250 - val_loss: 0.9487 - val_dense_30_loss: 0.1013 - val_binary_output_loss: 0.8474 - val_dense_30_accuracy: 0.0490 - val_binary_output_accuracy: 0.4850
# Epoch 30/50
# 25/25 [==============================] - 0s 13ms/step - loss: 0.6547 - dense_30_loss: 0.1011 - binary_output_loss: 0.5536 - dense_30_accuracy: 0.0494 - binary_output_accuracy: 0.7262 - val_loss: 0.9636 - val_dense_30_loss: 0.1018 - val_binary_output_loss: 0.8618 - val_dense_30_accuracy: 0.0475 - val_binary_output_accuracy: 0.4950
# Epoch 31/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.6557 - dense_30_loss: 0.1013 - binary_output_loss: 0.5544 - dense_30_accuracy: 0.0491 - binary_output_accuracy: 0.7125 - val_loss: 0.9878 - val_dense_30_loss: 0.1038 - val_binary_output_loss: 0.8840 - val_dense_30_accuracy: 0.0460 - val_binary_output_accuracy: 0.5200
# Epoch 32/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.6441 - dense_30_loss: 0.1016 - binary_output_loss: 0.5426 - dense_30_accuracy: 0.0500 - binary_output_accuracy: 0.7250 - val_loss: 0.9855 - val_dense_30_loss: 0.1012 - val_binary_output_loss: 0.8843 - val_dense_30_accuracy: 0.0505 - val_binary_output_accuracy: 0.5200
# Epoch 33/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.6183 - dense_30_loss: 0.1014 - binary_output_loss: 0.5169 - dense_30_accuracy: 0.0492 - binary_output_accuracy: 0.7575 - val_loss: 1.0232 - val_dense_30_loss: 0.1021 - val_binary_output_loss: 0.9212 - val_dense_30_accuracy: 0.0495 - val_binary_output_accuracy: 0.4600
# Epoch 34/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.6106 - dense_30_loss: 0.1011 - binary_output_loss: 0.5094 - dense_30_accuracy: 0.0487 - binary_output_accuracy: 0.7550 - val_loss: 1.0015 - val_dense_30_loss: 0.1017 - val_binary_output_loss: 0.8998 - val_dense_30_accuracy: 0.0500 - val_binary_output_accuracy: 0.4850
# Epoch 35/50
# 25/25 [==============================] - 0s 15ms/step - loss: 0.5846 - dense_30_loss: 0.1007 - binary_output_loss: 0.4839 - dense_30_accuracy: 0.0489 - binary_output_accuracy: 0.7775 - val_loss: 1.0547 - val_dense_30_loss: 0.1017 - val_binary_output_loss: 0.9530 - val_dense_30_accuracy: 0.0480 - val_binary_output_accuracy: 0.4950
# Epoch 36/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5741 - dense_30_loss: 0.1011 - binary_output_loss: 0.4729 - dense_30_accuracy: 0.0514 - binary_output_accuracy: 0.7875 - val_loss: 1.0566 - val_dense_30_loss: 0.1020 - val_binary_output_loss: 0.9546 - val_dense_30_accuracy: 0.0515 - val_binary_output_accuracy: 0.5050
# Epoch 37/50
# 25/25 [==============================] - 0s 16ms/step - loss: 0.5661 - dense_30_loss: 0.1022 - binary_output_loss: 0.4639 - dense_30_accuracy: 0.0520 - binary_output_accuracy: 0.7763 - val_loss: 1.0852 - val_dense_30_loss: 0.1042 - val_binary_output_loss: 0.9810 - val_dense_30_accuracy: 0.0445 - val_binary_output_accuracy: 0.4800
# Epoch 38/50
# 25/25 [==============================] - 0s 16ms/step - loss: 0.5336 - dense_30_loss: 0.1017 - binary_output_loss: 0.4319 - dense_30_accuracy: 0.0492 - binary_output_accuracy: 0.8138 - val_loss: 1.1741 - val_dense_30_loss: 0.1024 - val_binary_output_loss: 1.0718 - val_dense_30_accuracy: 0.0490 - val_binary_output_accuracy: 0.4850
# Epoch 39/50
# 25/25 [==============================] - 0s 15ms/step - loss: 0.5206 - dense_30_loss: 0.1038 - binary_output_loss: 0.4168 - dense_30_accuracy: 0.0506 - binary_output_accuracy: 0.8175 - val_loss: 1.2013 - val_dense_30_loss: 0.1109 - val_binary_output_loss: 1.0904 - val_dense_30_accuracy: 0.0505 - val_binary_output_accuracy: 0.5350
# Epoch 40/50
# 25/25 [==============================] - 0s 14ms/step - loss: 0.4841 - dense_30_loss: 0.1065 - binary_output_loss: 0.3776 - dense_30_accuracy: 0.0507 - binary_output_accuracy: 0.8375 - val_loss: 1.2639 - val_dense_30_loss: 0.1068 - val_binary_output_loss: 1.1570 - val_dense_30_accuracy: 0.0465 - val_binary_output_accuracy: 0.5050
# Epoch 41/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4664 - dense_30_loss: 0.1048 - binary_output_loss: 0.3616 - dense_30_accuracy: 0.0521 - binary_output_accuracy: 0.8475 - val_loss: 1.2719 - val_dense_30_loss: 0.1049 - val_binary_output_loss: 1.1670 - val_dense_30_accuracy: 0.0485 - val_binary_output_accuracy: 0.4900
# Epoch 42/50
# 25/25 [==============================] - 0s 11ms/step - loss: 0.4132 - dense_30_loss: 0.1035 - binary_output_loss: 0.3098 - dense_30_accuracy: 0.0523 - binary_output_accuracy: 0.8838 - val_loss: 1.3296 - val_dense_30_loss: 0.1046 - val_binary_output_loss: 1.2249 - val_dense_30_accuracy: 0.0480 - val_binary_output_accuracy: 0.4700
# Epoch 43/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3869 - dense_30_loss: 0.1034 - binary_output_loss: 0.2835 - dense_30_accuracy: 0.0529 - binary_output_accuracy: 0.8900 - val_loss: 1.4290 - val_dense_30_loss: 0.1047 - val_binary_output_loss: 1.3242 - val_dense_30_accuracy: 0.0480 - val_binary_output_accuracy: 0.4900
# Epoch 44/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.4123 - dense_30_loss: 0.1098 - binary_output_loss: 0.3025 - dense_30_accuracy: 0.0492 - binary_output_accuracy: 0.8675 - val_loss: 1.4112 - val_dense_30_loss: 0.1157 - val_binary_output_loss: 1.2955 - val_dense_30_accuracy: 0.0425 - val_binary_output_accuracy: 0.5100
# Epoch 45/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.3495 - dense_30_loss: 0.1071 - binary_output_loss: 0.2424 - dense_30_accuracy: 0.0504 - binary_output_accuracy: 0.9087 - val_loss: 1.4470 - val_dense_30_loss: 0.1064 - val_binary_output_loss: 1.3406 - val_dense_30_accuracy: 0.0460 - val_binary_output_accuracy: 0.4950
# Epoch 46/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.3179 - dense_30_loss: 0.1052 - binary_output_loss: 0.2128 - dense_30_accuracy: 0.0530 - binary_output_accuracy: 0.9237 - val_loss: 1.6325 - val_dense_30_loss: 0.1071 - val_binary_output_loss: 1.5254 - val_dense_30_accuracy: 0.0460 - val_binary_output_accuracy: 0.5000
# Epoch 47/50
# 25/25 [==============================] - 0s 9ms/step - loss: 0.2866 - dense_30_loss: 0.1063 - binary_output_loss: 0.1803 - dense_30_accuracy: 0.0539 - binary_output_accuracy: 0.9350 - val_loss: 1.7042 - val_dense_30_loss: 0.1083 - val_binary_output_loss: 1.5958 - val_dense_30_accuracy: 0.0460 - val_binary_output_accuracy: 0.4950
# Epoch 48/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2565 - dense_30_loss: 0.1055 - binary_output_loss: 0.1510 - dense_30_accuracy: 0.0521 - binary_output_accuracy: 0.9475 - val_loss: 1.8543 - val_dense_30_loss: 0.1076 - val_binary_output_loss: 1.7468 - val_dense_30_accuracy: 0.0420 - val_binary_output_accuracy: 0.5150
# Epoch 49/50
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2598 - dense_30_loss: 0.1077 - binary_output_loss: 0.1521 - dense_30_accuracy: 0.0529 - binary_output_accuracy: 0.9500 - val_loss: 1.9190 - val_dense_30_loss: 0.1098 - val_binary_output_loss: 1.8091 - val_dense_30_accuracy: 0.0510 - val_binary_output_accuracy: 0.5150
# Epoch 50/50
# 25/25 [==============================] - 0s 10ms/step - loss: 0.2106 - dense_30_loss: 0.1082 - binary_output_loss: 0.1024 - dense_30_accuracy: 0.0527 - binary_output_accuracy: 0.9725 - val_loss: 1.9943 - val_dense_30_loss: 0.1113 - val_binary_output_loss: 1.8830 - val_dense_30_accuracy: 0.0450 - val_binary_output_accuracy: 0.4900
# 1/1 [==============================] - 1s 550ms/step
# Predicted Sequence: [[[ 0.54411674  0.7707642   0.49372342  0.69172174  0.5205768
#     0.6457886   0.5554383   0.6507038   0.7747755   0.74932873
#     0.45969954  0.5946907   0.566247    0.63933855  0.683769
#     0.77335006  0.69185966  0.6961073   0.5491131   0.6458108 ]
#   [ 0.44741768  0.4611136   0.1707597   0.35720122  0.42490277
#     0.58109766  0.45260587  0.34372953  0.71284175  0.74022853
#     0.4414299   0.49995285  0.670436    0.4196941   0.57302856
#     0.48922622  0.8314369   0.30260277  0.7355296   0.15447636]
#   [ 0.4815585   0.06793307 -0.0642508   0.12737754  0.32979566
#     0.39399117  0.21376435  0.65982324  0.45307016  0.5693422
#     0.42420712  0.7038851   0.5890887   0.28983966  0.607315
#     0.06674083  0.73509085  0.2912687   0.677683    0.22440977]
#   [ 0.5104789   0.23614115  0.3120069   0.131192    0.33977672
#     0.59073323  0.38426626  0.8925775   0.51241386  0.29971403
#     0.3266801   0.5693999   0.71876913  0.375878    0.9002558
#     0.454329    0.9828249   0.3622778   0.6180049   0.55416685]
#   [ 0.48474002  0.1202404   0.16587937  0.1567226   0.32575166
#     0.37947583  0.41579807  0.6032828   0.3378072   0.3766203
#     0.38594186  0.4538101   0.50313103  0.22185552  0.5372541
#     0.21327485  0.6801357   0.24398845  0.55008334  0.22118932]
#   [ 0.429241    0.2388657   0.53464067  0.33283782  0.4300521
#     0.49064374  0.6203369   0.80068195  0.5106513   0.33779094
#     0.40794247  0.51897544  0.5257603   0.43930256  0.5942506
#     0.47049475  0.6277181   0.20224874  0.46029705  0.7391734 ]
#   [ 0.4311774   0.59554064  0.66868216  0.50751877  0.43854493
#     0.5344893   0.5747434   0.31643346  0.8042233   0.5296624
#     0.44396776  0.31766883  0.39822462  0.5425338   0.49307135
#     0.80140334  0.58309895  0.43250015  0.39771283  0.4776839 ]
#   [ 0.53524315  0.16937286  0.2549859   0.33770806  0.30159715
#     0.4896081   0.39988512  0.43066847  0.5450995   0.6490077
#     0.48501515  0.682492    0.50307876  0.5245813   0.5694956
#     0.2981481   0.7214018   0.3057028   0.74263084  0.22255264]
#   [ 0.51042527  0.39220378  0.3072129   0.03067127  0.32895058
#     0.47393137  0.5017502   0.8371148   0.67722124  0.44201767
#     0.40056717  0.5296176   0.44172955  0.51637965  0.65706074
#     0.52263266  0.7629427   0.363396    0.6534105   0.54668874]
#   [ 0.32662815  0.02839203 -0.03938407  0.27957684  0.40793574
#     0.22422042  0.19632041  0.2762947   0.59391445  0.5597317
#     0.57841074  0.4706819   0.54726994  0.28559542  0.2921552
#     0.31929487  0.4565001   0.380287    0.4394169  -0.00854741]]]
# Binary Prediction: [[0.9416061]]

# %%
#torch seq2seq classification
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

class Encoder(nn.Module):
    def __init__(self, input_dim, hidden_dim, n_layers, dropout):
        super(Encoder, self).__init__()
        self.rnn = nn.GRU(input_dim, hidden_dim, n_layers, dropout=dropout)

    def forward(self, src):
        outputs, hidden = self.rnn(src)
        return hidden

class Decoder(nn.Module):
    def __init__(self, output_dim, hidden_dim, n_layers, dropout):
        super(Decoder, self).__init__()
        self.rnn = nn.GRU(output_dim, hidden_dim, n_layers, dropout=dropout)
        self.fc_out = nn.Linear(hidden_dim, output_dim)
        self.fc_binary = nn.Linear(hidden_dim, 1)  # Ubah dimensi keluaran menjadi 1
        self.dropout = nn.Dropout(dropout)

    def forward(self, input, hidden):
        output, hidden = self.rnn(input.unsqueeze(0), hidden)
        prediction = self.fc_out(output.squeeze(0))
        binary_output = torch.sigmoid(self.fc_binary(output.squeeze(0)))  # Tetap gunakan sigmoid untuk output biner
        return prediction, hidden, binary_output

class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, hidden_dim,device):
        super(Seq2Seq, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.fc_binary = nn.Linear(hidden_dim, 1)
        self.device = device

    def forward(self, src, trg, teacher_forcing_ratio = 0.5):
        trg_len = trg.shape[0]
        trg_vocab_size = self.decoder.fc_out.out_features
        outputs = torch.zeros(trg_len, trg.shape[1], trg_vocab_size).to(device)
        binary_outputs = torch.zeros(trg_len, trg.shape[1], 1).to(self.device)

        hidden = self.encoder(src)
        input = trg[0,:,:]

        for t in range(1, trg_len):
            output, hidden, binary_output = self.decoder(input, hidden)
            outputs[t] = output
            binary_outputs[t] = binary_output
            teacher_force = np.random.random() < teacher_forcing_ratio
            input = trg[t,:,:] if teacher_force else output

        final_binary_output = torch.sigmoid(self.fc_binary(output.squeeze(0)))
        return outputs, final_binary_output

# input_dim = x_train_tseries.shape[2]
# hidden_dim = 64
# output_dim = x_train_tseries.shape[2]
# n_layers = 2
# dropout = 0.5

input_dim = 20
hidden_dim = 64
output_dim = 20
n_layers = 2
dropout = 0.5

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

encoder = Encoder(input_dim, hidden_dim, n_layers, dropout)
decoder = Decoder(output_dim, hidden_dim, n_layers, dropout)
model = Seq2Seq(encoder, decoder, hidden_dim,device).to(device)

optimizer = optim.Adam(model.parameters())
criterion = nn.MSELoss()
binary_criterion = nn.BCELoss()

def train(model, iterator, optimizer, criterion, binary_criterion, clip):
    model.train()
    epoch_loss = 0

    for i, batch in enumerate(iterator):
        src = batch['src'].to(device)
        trg = batch['trg'].to(device)
        trg_binary = batch['trg_binary'].to(device)

        optimizer.zero_grad()

        output, binary_output = model(src, trg)

        output_dim = output.shape[-1]
        output = output[1:].view(-1, output_dim)
        trg = trg[1:].view(-1, output_dim)

        binary_output = binary_output[1:].view(-1)
        trg_binary = trg_binary[1:].view(-1)

        loss = criterion(output, trg) + binary_criterion(binary_output, trg_binary)
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        optimizer.step()

        epoch_loss += loss.item()

    return epoch_loss / len(iterator)

# Dummy data
src_data = torch.rand(10, 32, input_dim).to(device)  # (sequence length, batch size, num_features)
trg_data = torch.rand(10, 32, output_dim).to(device)  # (sequence length, batch size, num_features)
trg_binary_data = torch.randint(0, 2, (10, 32, 1)).float().to(device)  # (sequence length, batch size, 1)

# Dummy iterator
class DummyIterator:
    def __iter__(self):
        return iter([{'src': src_data, 'trg': trg_data, 'trg_binary': trg_binary_data}])

iterator = DummyIterator()

# Train the model
clip = 1
for epoch in range(10):
    train_loss = train(model, iterator, optimizer, criterion, binary_criterion, clip)
    print(f'Epoch: {epoch+1:02}, Train Loss: {train_loss:.4f}')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-9dd9c91193e7> in <cell line: 123>()
#     122 clip = 1
#     123 for epoch in range(10):
# --> 124     train_loss = train(model, iterator, optimizer, criterion, binary_criterion, clip)
#     125     print(f'Epoch: {epoch+1:02}, Train Loss: {train_loss:.4f}')
#
# <ipython-input-11-9dd9c91193e7> in train(model, iterator, optimizer, criterion, binary_criterion, clip)
#      88         optimizer.zero_grad()
#      89
# ---> 90         output, binary_output = model(src, trg)
#      91
#      92         output_dim = output.shape[-1]
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# <ipython-input-11-9dd9c91193e7> in forward(self, src, trg, teacher_forcing_ratio)
#      52             input = trg[t,:,:] if teacher_force else output
#      53
# ---> 54         final_binary_output = torch.sigmoid(self.fc_binary(output.squeeze(0)))
#      55         return outputs, final_binary_output
#      56
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     114
#     115     def forward(self, input: Tensor) -> Tensor:
# --> 116         return F.linear(input, self.weight, self.bias)
#     117
#     118     def extra_repr(self) -> str:
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (32x20 and 64x1)
